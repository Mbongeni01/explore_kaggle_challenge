# %% [markdown]
# # Climate Change EDSA challenge

# %% [markdown]
# ### Import required packages

# %%
import numpy as np
import pandas as pd
import re

import nltk
from nltk.tokenize import RegexpTokenizer
from nltk import TreebankWordTokenizer, SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score

import string
import urllib

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mbongenimlotha/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mbongenimlotha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Read in the data

# %%
train_df = pd.read_csv(r'train.csv')
test_df = pd.read_csv(r'test.csv')

# %%
train_df.head()
# Out:
#    sentiment                                            message  tweetid
# 0          1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1          1  It's not like we lack evidence of anthropogeni...   126103
# 2          2  RT @RawStory: Researchers say we have three ye...   698562
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954

# %%
test_df.head()
# Out:
#                                              message  tweetid
# 0  Europe will now be looking to China to make su...   169760
# 1  Combine this with the polling of staffers re c...    35326
# 2  The scary, unimpeachable evidence that climate...   224985
# 3  @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263
# 4  RT @FakeWillMoore: 'Female orgasms cause globa...   872928

# %%
train_df.sentiment.value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %%
train_df['message'][0]
# Out:
# 'polyscimajor epa chief doesnt think carbon dioxide is main cause of global warming and wait what httpstcoyelvcefxkc via mashable'

# %%
punc_removed=[]
for message in train_df['message']:
    no_punc = ''.join([x for x in message.lower() if x not in string.punctuation])
    sentence=no_punc.replace('{html}',"")
    sentence=sentence.replace('rt',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_special = re.sub(r'[^ \nA-Za-z0-9À-ÖØ-öø-ÿЀ-ӿ/]+', '', cleantext)
    rem_url=re.sub(r'http\S+', '',rem_special)
    rem_num = re.sub('[0-9]+', '', rem_url)
    rem_space = re.sub(r'@"\t|\n|\r', '', rem_num)
    rem_last = re.sub(r'ãââ', '', rem_space)
    punc_removed.append(rem_last)

# %%
punc_removed
# Out:
# ['polyscimajor epa chief doesnt think carbon dioxide is main cause of global warming and wait what  via mashable',
#  'its not like we lack evidence of anthropogenic global warming',
#  ' rawstory researchers say we have three years to act on climate change before its too late  ',
#  'todayinmaker wired   was a pivotal year in the war on climate change ',
#  ' soynoviodetodas its  and a racist sexist climate change denying bigot is leading in the polls electionnight',
#  'woh a read whether you do or dont believe in climate change  ',
#  ' thenation mike pence doesnt believe in global warming or that smoking causes lung cancer ',
#  ' makeandmendlife six big things we can all do today to fight climate change or how to be a climate activist  h',
#  'aceofspadeshq my yo nephew is inconsolable he wants to die of old age like me but will perish in the fiery hellscape of climate change',
#  ' paigetweedy no offense but like how do you just not believe in global warming',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'i do hope people who are vocal about climate change also powering their homes with renewable energy like goodenergy',
#  ' tveitdal we only have a  percent chance of avoiding dangerous global warming a study finds  ',
#  ' alifaith oh my godtrumps government removes climate change page from epa website hours ahead of climatemarch',
#  'fossil fuel giant exxonmobil misled the public about climate change harvard academics conclude ',
#  ' glblctzn i dont wanna live forever  and nothing will because climate change  taylorswift zaynmalik ',
#  ' jackholmes issues scrubbed from  today civil rights climate change lgbt healthcare ',
#  ' patagonia if our elected leaders fail to approach the environment amp climate change as serious issues wohy of urgency amp action it wi',
#  ' sensanders we have a presidentelect who doesnt believe in climate change millions of people are going to have to say mr t',
#  'calum tweets abt reunitingish w the castsees replies begging him to come to their countriescalum goes back to ing climate change',
#  ' ccities  c mayors representing m citizens have urged g leaders to saveourplanet from climate change you can too',
#  ' worldwildlife how climate change impacts wildlife  cop eahtomarrakech ',
#  'we also met this guy he let us in on some truth about climate change and gay people not existing ',
#  'scientists say climate change wiped out an entire underwater ecosystem againclimate ',
#  ' tammygrubb obama raises climate change you better vote for candidates who believe in science obamaunc',
#  'i hate to say this but mental health will be pretty low on the menu when climate change hits food production an ',
#  'bangladesh confronting climate change head on  ',
#  'hey there michaels vetted and approved marketbased strategies for tackling climate change are suppoed by a majority of cdns cdnpoli',
#  'sally kohns latest evidence of climate change proves she is not a sma person  via twitchyteam need we say more',
#  ' staalkradio first the public understands climate change better than congress why johnholdren corybooker neiltyson explain htt',
#  'jnpftw are these the same scientists that denounce climate change its not a choice',
#  ' honey a guide to global warming paris pact and the us role demforce theresistance uniteblue ',
#  ' latimes atmospheric rivers fueled by climate change could decimate wild oysters in san francisco bay  ',
#  'denying climate change ignores basic science',
#  'bgr  china practically says trump lied about climate change ',
#  ' berniesanders imvotingbecause the future of the planet is at stake hillary clinton will combat climate change donald trump thinks i',
#  ' independent trumps team removed climate change data from the white house website they may be breaking the law',
#  ' deboraheha toxic soils aquifers vast amts of wasted  waste water runaway climate change  what pa of gas fracking don',
#  ' bettybowers america where climate change is unproven to people  sure a guy called noah fit all the worlds animals on hi',
#  'we ve dealt with simple issues like climate change and energy policy now the complex issues mal vs tones qanda',
#  ' foramerica they protested in suppo of climate change at the womansmarch and then did their pa to help the environment ',
#  ' climate targets nations are playing the long game in fighting global warming  via conversationedu',
#  ' thedailybeast trumps climate change denial could cost us  trillion  ',
#  ' andrewsharp win probability is bullshit man i saw the nba finals and thats when i knew global warming isnt real',
#  ' washingtonpost the alaskan tundra is filling the atmosphere with carbon dioxide worsening climate change ',
#  ' thetorontosun from sunlorrie indian environmentalist calls out dicaprio in his own documentary on climate change',
#  'realdonaldtrump carbon tax is a globalist idea to enslave the worlds population it is the whole reason for propagating global warming',
#  'will anyone who suppos trumps view of climate change non polluter cronie please step forward resist impeach ',
#  ' stevesgoddard we had winds close to  mph in the area this afternoon i would blame climate change except that this happens pr ',
#  ' starbuck world food supplies at risk as climate change threatens international trade warn expes  ',
#  ' foxnews macron my charm may have changed trumps mind on climate change  ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'chris who is it then that initially talked about climate changeme  thinked for three seconds   the europea ',
#  'do you approve of the executive order realdonaldtrump is due to sign re climate change and the environment',
#  'trump doesnt believe in global warming and hes going to be the president of the united states of america fuck',
#  ' kelkulus irony florida a state in danger of being washed away due to rising sea levels just elected a guy who denies climate change',
#  'misslizzynj lmao  snowflakes  complaining about snowflakes  in winter global warming ',
#  ' dawndawn this is one of arnold schwarzeneggers vehicles he is now whining about climate changehows his maidillegal orhttp',
#  'glennf they are calling to the great space cylinder to save them from global warming',
#  ' greenpeaceeasia pollution from india and china has reached the stratosphere which could speed up global warming ',
#  ' unep the citiesclimfin lays out how cities and subnational bodies can finance solutions to climate change',
#  'these house republicans say climate change is real and its time to fight it  by ninaburleigh',
#  'but global warming is a hoax though ',
#  ' kylegriffin nyt reviewed a draft climate change rpt by fed scientists directly contradicting the admins global warming claims ',
#  ' fuckofflaine jjxrry spacex quebanjesus antarctica is so big lmao how is global warming real like nigga just use an air conditioner',
#  'my two cents on the global political leadership on climate change in a trump era ',
#  ' bbcbreaking uk government signs paris agreement worlds first comprehensive treaty on tackling climate change ',
#  ' hope china tells trump that climate change isnt a hoax it invented  via business lol china schooling t',
#  ' motherjones here are the races to watch if you care about global warming  ',
#  'uscgpacificnw nsf these icebreaking ships are the primary cause of climate change let the arctic freeze over amp stay away from there',
#  ' kelkulus irony florida a state in danger of being washed away due to rising sea levels just elected a guy who denies climate change',
#  'if global warming doesnt exist why is club penguin shutting down ',
#  ' profpcdohey need economists to incorporate the reality of climate change in their thinking amp we all need to listen ',
#  ' ushrn as we fight for human rights were also facing the disastrous impacts of climate change ',
#  ' cernovich is climate change real ',
#  ' ahamiltonspirit there is no question climate change is manmade if you have doubts and havent seen an inconvenient truth please',
#  'alphageekstr the process of climate change it occurs naturally but not at these extreme levels well eventually have severe droughts',
#  ' roschneider neoliberalism has conned us into fighting climate change as individuals  main lukacs ',
#  ' davidsirota must read rick perry ordered texas legislature to kill bill requiring state agencies to prepare for climate change ',
#  ' sensanders we have a presidentelect who doesnt believe in climate change thats frightening for this country and the world',
#  'so hot due to global warming',
#  ' ldnenvironment weve a few sho term opps working on climate change amp energy send us your cv or qs to environmentlondongovuk h',
#  ' markbaileymp fed energyenvt minister joshfrydenberg refused to allow term climate change in coag energy council communique despit',
#  ' jadorelacouture the fact that leonardo dicaprio met with trump to discuss climate change a man',
#  ' verge google eahs timelapse update illustrates  years of climate change  ',
#  ' sethmacfarlane hrc proposes installing half a billion solar panels by the end of her first term trump thinks climate change is a hoax',
#  'beforetheflood everyone must watch this people must understand global warming is very real leodicaprio ',
#  'if this doesnt shake you up about climate change then nothing ever will ',
#  ' smithsonianenv sercs roy rich amp colleagues create a buzz in germany for their global warming simulation ',
#  ' eahjustice noaa repo  was nd hottest year in history one more reason to fight climate change deniers in trump admin gt',
#  'conservatives just love denying science huh from climate change to believing that feilization of an egg  an automatic human life',
#  'senior air quality and climate change specialist as a senior air  airquality climatechange greenhousegas',
#  'come check out our events about climate change srhpl ',
#  'to think  million could have gone towards alleviating povey reducing climate change or improving healthcare call me mad but',
#  'cnn its a protest against global warming the are not stupid',
#  ' ronaldklain as trump decides on paris briancdeese amp i team up in washingtonpost to warn about climate change and epidemics ',
#  ' savingoceans lack of climate change action can potentially hu future fishermen jobs ',
#  'yet another trump advisor is clueless on climate change by climateprogress ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'us environmental agency chief says humans contribute to global warming  ',
#  'so we have a director of epa who is a climate change denier no a coal lobbies to as deputy epa chief environment ',
#  ' irisrimon the chinese just broke massive iceberg in antarctica as pa of their global warming hoax',
#  ' thinkprogress where are rex tillersons climate change emails',
#  ' mthgd if global warming isnt real why did club penguin shut down',
#  ' ndenicolamd  doctors agree climate change is making us sick eahday marchforscience healthandclimate',
#  ' tristinc our president think climate change is a hoax made by the chinese amp our vice president thinks being gay is a curable disease',
#  ' of ghg via resevoirs are methane resevoirs play a substantial role in global warming  ',
#  ' fruitloopian why is there snow in march if we have global warming',
#  ' greenharvard universities have a uniquely impoant role to play in the battle against climate change ',
#  ' sethmacfarlane are we looking at an america that officially believes climate change is a hoax sorry everybody else',
#  ' popsci ten of the ugliest animals threatened by climate change  ',
#  'realdonaldtrump potus you fucking idiot im a geologist amp studied climate change in college amp coauthored two papers on it  its real',
#  ' sensanders we have a presidentelect who doesnt believe in climate change millions of people are going to have to say mr t',
#  'can someone pls explain to me why its  in march global warming who',
#  ' natgeochannel watch beforetheflood right here as leodicaprio travels the world to tackle climate change  htt',
#  ' peta meat production is a leading cause of climate change water waste deforestation amp extinction worldveganday',
#  'explain that my global warming advocates ',
#  'syfys incorporated imagines future ravaged by climate change  via cnn ',
#  'prisonplanet wow wow finally climate change is not the evil now you wake up good',
#  ' drishtiias audio aicle environment after trumps decision what will be the form of paris climate change agreement',
#  ' nytnational white house budget proposal on climate change were not spending money on that anymore ',
#  'tomilahren kinda funny the professors talk shit trumpstersomg f them scientist climate change trumpserst idots kinda shows his base',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  ' sethmacfarlane hrc proposes installing half a billion solar panels by the end of her first term trump thinks climate change is a hoax',
#  ' lexiprez he is literally a climate change denierrip our planet ',
#  'realdonaldtrump  what about climate change its very real but you only care about ',
#  ' kloppholic imagine trying to convince yourself that global warming isnt real and instead a conspiracy wake up before its t',
#  'docrock so he is saying climate change is a hoax and every major scientific organization is a in on it',
#  'politicalsho piewagn dems are causing global warming stfu',
#  ' signordal new global warming study is terrible news for alarmists good news for plants animals an ',
#  'follow projectarcc if you want to hear more about what av and digital archivists can do about climate change activism avhack',
#  'if you dont believe in climate change then look at the polar bears that are going extinct because they have no land to live on',
#  'air pollution deaths expected to rise due to climate change   ',
#  'labour budgeting and climate change   the punch    climatechange',
#  'we dont have to hear antivaccersclimate change deniersaca killers out stop using your stupidity to try and kil ',
#  'reader questions science of climate change theories   climatechange',
#  'see the impacts of global warming ',
#  'one way to ave climate change the world should apply the method ',
#  ' foxandfriends new catholic priests expected to preach global warming to congregations repo says  foxnation ',
#  ' sasjabeslik meet chinas ecological migrants  people displaced by climate change ',
#  'china warns trump against abandoning climate change deal  via ft',
#  'science to the rescue as climate change threatens chocolate via new europe ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'zachheltzel people who believe in climate change also generally refuse to say that trans isnt real out loud so youre no better',
#  ' samjamesvelde its  degrees in early november in los angeles but you know according to trump global warming and climate change',
#  'come amp hear more about climate change and antarctica aclimate larsenc climatechangea ',
#  'the youths being almost  of kenyas pop are best line of defense against climate change amp food securityrobemburia richardmunang',
#  'cbsnews youre not going to get away with this we are going to call you out every single time all pages are gone inc fake climate change',
#  ' geographerjay trump wants to end nasa climate change research as real estate markets sta to slump due to climate change ',
#  ' charliedaniels im not worried about global warming but im terrified about global government',
#  ' jeffdsachs cnn panelists erupt over climate change  cnn video time to call out lies of trump koch brothers and heritage ',
#  'vp nasajohnson ask them to explain climate change to you',
#  ' jinjjarevil the way seokjin blinks is so adorable global warming stopstrees grow crime rate decreases ',
#  'im worried for our planet trump will do nothing for climate change',
#  'effect of methane on climate change could be  greater than we thought  via physorgcom',
#  ' astrokatie governments of several world powers are failing us on climate change we need to act without them if we want any hope for t',
#  ' benhulac asked if charges that exxonmobil withheld information on climate change tillerson declines to answer twice secretaryofst',
#  ' kamalaharris i stand with jerrybrowngov in saying that california will not back down on climate change ',
#  'steveengland have u considered doing a piece about it in your column steve inform ppl re impact of climate change on species amp habitats',
#  'rjsalmond was already out after climate change denial but either of the above would do which is my loss as well',
#  'quiz on us cultural heritageclimate change disclaimer i dont agree w all the answers but still interesting ',
#  ' benwikler dont worry its just the natural process of anthropogenic climate change rendering the eah uninhabitable',
#  'look whos back in town and thank you global warming  enjoying a quick trip to brown county state park on this  degree november day',
#  'alanresnicks the  horsemen of the apocalypse famine war death pestilence and global warming',
#  'global warming is a hoax perpetrated by the chinese',
#  ' safetypindaily us federal depament is censoring use of term climate change emails reveal  by olliemilman ',
#  'puffnpuffin stevemaintogo billnye bumfonline could someone link me the journal for his reviewed aicle on climate change isnt one',
#  'guess i have global warming to thank',
#  ' hawaiidelilah so trump went to ivanka and a repoer for insights on climate change not scientists two women with no expeis',
#  'conservative columnist under siege after ny times debut on climate change via fox news ',
#  ' wqs pakistan is the th most vulnerable country in terms of climate change whats our most experienced prime minister has to say about',
#  'mei mains against global warming',
#  ' indyusa trumps budget director just said combating climate change is a waste of money ',
#  ' ajb we knock ourselves out over brexit and trump but i think climate change will bury both of those issuesbut i really hope im w',
#  'us to world on climate change drop dead nobel scientist such ignorance is shocking ',
#  'trudeau must put emphasis on defence if he wants trump onside for trade climate change  via nationalpost',
#  ' carbongate physicist  co does not cause climate change it responds to it  video ',
#  ' lastweektonight if you dont believe manmade global warming is a a silly issue give to the natural resources defense council ',
#  ' thehill rahm emanuel posts climate change webpage deleted by trump administration  ',
#  ' jackposobiec soon the altright will be blamed for global warming and gingivitis ',
#  'deanofcomedy followed closely by climate change deniers and wall street executives',
#  'agreed manmade climate change is a manmade hoax innit ',
#  'sdg is a call to take urgent action to combat climate change and its impacts join the movement ',
#  ' bradleym juddlegum me to my  yo kid do you believe in climate changekid its a scientific fact so it doesnt matte',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  ' tamorley zekejmiller but why a carbon tax isnt all that climate change stuff is hokum',
#  ' energydesk historic coal fall may have profound impact on global effos to tackle climate change  ',
#  'when china calls out donald trump on climate change you know its bad ',
#  ' literateliberal leading global warming deniers just told us what they want trump to do  via motherjones',
#  ' billmckibben exxonmobil has a long history of peddling misinformation on climate change elizkolbe in newyorker exxonknew ',
#  ' pablorodas climatechange p  west coast states to fight climate change even if trump does not ',
#  ' ecointernet us secretary of state rex tillerson signs arctic agreement for action on climate change antinuclear ',
#  'stephen hawking has a message for trump dont ignore climate change  ',
#  ' telesurenglish one of jamaicas iconic beaches is vanishing thanks to climate change ',
#  ' mrdenmore apa from taking us to the brink of recession doubling the deficit and making us a pariah on refugees amp climate change th',
#  ' mikebeacham fed scientist cooked climate change books ahead of obama presentation nomorescamsnomoredemocratsdraintheswamp http',
#  ' natgeochannel one of the easiest ways to help combat climate change in your daily life is to stop eating beef heres why',
#  'effects of climate change ',
#  ' marcuschown with a denier in the white house how do we deal with the global warming catastrophe that threatens  billion of us with',
#  ' nzaegel effects of climate change may wreak havoc on mental health doctors say  via upi',
#  'how do people argue climate change',
#  ' glblctzn when you hear trumps new epa director says carbon doesnt cause climate change  ',
#  ' countermoonbat the people who predicted pas of manhattan would be underwater by  due to climate change are concerned about fake',
#  ' thinkprogress brace yourself for a bitterly cold winter as climate change shifts the polar voex  ',
#  ' senatormrobes how much global warming will finkel blueprint stop by none so why would we deindustrialise our economy fo',
#  ' business china tells trump climate change isnt a hoax it invented  ',
#  ' turnscoat why cant we agree that climate change is our number one priority',
#  ' prisionplaneta scottadamssays scientists and studies just as global warming only that they choose to show us the ones they like htt',
#  ' climatekeith saskatchewan ag provincial govt has no plan policies or target to address climate change  skpol',
#  'they asked me what my inspiration was i told em global warming',
#  ' energydesk exxon shareholders have moved to force the company to disclose the risk climate change poses to its business',
#  ' mobilizeclimate we must stop treating the effects of climate change as some far off doomsday they are here they are now',
#  'i think i just solved the climate change problem i just told my kids dont fix global warming now we just sit back and wait dadlife',
#  ' natureorg world leaders reaffirm their commitment to climate change and the parisagreement  ',
#  ' jacobwhitesides i think thats global warming not christmas ',
#  ' ecointernet john roughan we will miss a sceptical voice on climate change new zealand herald  environment',
#  ' chejackson not that climate change is real or anything but its  in columbus oh right now in november realdonaldtrump',
#  'rex tillerson refuses to admit exxonknew about climate change decades ago  via huffpostpol',
#  ' wakmax just talk about climate change says alicebell  itll make you feel better about it go on then  have a read ',
#  ' duycks join us tomorrow for hrc event on childrenrights in context of climate change key message protect and empower',
#  ' unep how to boost funding for developing countries to adapt to the effects of climate change is a key issue at cop',
#  ' paulhbeckwith listen folks to a storyabout the evil twinof climate changethe oceans on acid ',
#  ' huffingtonpost china to trump climate change is not a chinese hoax  ãåâãâï cmdangelo ',
#  ' businessinsider apple is borrowing  billion to fight climate change  ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  ' bradydennis cdc abruptly cancels longplanned conference on climate change and health ',
#  'tell us your story now about climate change in our story contest climatechange  ',
#  'zrastall climate change is fakenews',
#  ' popsci a river in canada just turned to piracy because of global warming  ',
#  ' mrbrexit good news that realdonaldtrump is looking to ditch the paris agreement and bust open the climate change myth maga stepfo',
#  ' adriangeolopez people still dont believe in global warming  what can we do especially with the president pulling out of the p',
#  'please  health fitness is it too late to reverse global warmingampquot this is what scientists have to ',
#  ' scholaurship and this motherfucker doesnt believe in climate change i',
#  ' petraau more than  countries just subtweeted trump on global warming ',
#  'arizonapatriot joelpollak gabyendingstory at least obama isnt a christianextremist who thinks global warming amp evolution are hoaxes',
#  ' thedailyclimate frogs heading uphill to escape climate change india timesofindia ',
#  'us climate change campaigner dies snorkeling at greatbarrierreef greatbarrierreef ',
#  ' lianamaeby well on the plus side climate change isnt real anymore',
#  'robydalvik kalem ini karena faktor global warming air laut naik',
#  ' climatechangrr us sends much smaller team to climate talks in bonn  climate home  climate change news  http',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'conversation will go morning ahur cold out yes mal global warming obviously fake agreed ahur whos thi ',
#  ' natgeophotos although climate change can be a scary topic ice can be insanely unimaginably beautiful ',
#  'realdonaldtrump you want  be everyones president how about doing something progressive for us fight climate change and protect the env',
#  'exxon the only hero of global warming kicked saving the eah but selected money ',
#  'impacts of climate change include job losses business interruptions worsening working  by un via cnvey',
#  ' sensanders we have a presidentelect who doesnt believe in climate change thats frightening for this country and the world',
#  ' taylorandbrown i think the number one thing that bothers me about trump being president is that hes going to defund climate change re',
#  ' washtimes climate change whistleblower alleges noaa manipulated data to hide global warming pause  washtimes noaa',
#  'exxonmobil at exxon rex tillerson repoedly used alias for emails about climate change read more  xom',
#  ' illuminateboys i cant believe there are politicians who believe that climate change is fake and these are the people working for our',
#  'jackposobiec the global warming is caused by her cabbage fas',
#  'i was thinking the same thing same goes with climate change when there are other impoant issues that effect amer ',
#  ' simonwest brilliant caoon sums up realdonaldtrump decision to cancel barackobama climate change policies itisreal',
#  ' jamespeshaw nzgreens it gets you an end to povey in new zealand it gets you clean water and action on climate change',
#  'adam adamcurry maakte al  keer zijn no agenda show  leuk info over global warming ',
#  ' shadbase shadbase people who dont believe in global warming explain this',
#  ' berniesanders imvotingbecause the future of the planet is at stake hillary clinton will combat climate change donald trump thinks i',
#  ' uniocracy theyll tell you theyre doing it to save you from global warming theyre lying  opchemtrails',
#  ' conversationedu sea tules have been around for  million years but the pace of climate change is an existential challenge',
#  'lawlib hey we have a new board for bouncing ideas on climate change are you interested ',
#  'erry the real reason to fight climate change  ccol ',
#  ' newsfakenews todd starnes hey npr  take your global warming nonsense about kids and blow it out your f tailpipe ',
#  ' guardianeco stopping global warming is only way to save great barrier reef scientists warn greatbarrierreef ',
#  'nobamadotcom libbyraffey bizpacreview funny how the left scream their allegiance to science on global warming but not this issue',
#  'lisalsong another horrifying outcomes of global warming',
#  ' wsj in rebuke to trump policy ge ceo immelt says climate change is real ',
#  ' stevevsninjas its ãâf so climate change is a liethats  data point like u met me amp concluded all men are white and speak englis',
#  ' sierraclubwi pollutingpruitt thinks human impact on climate change subject to continued debate its not climatefacts ',
#  ' countermoonbat the people who predicted pas of manhattan would be underwater by  due to climate change are concerned about fake',
#  ' thehill arnold schwarzenegger teams up with macron to fight climate change  ',
#  ' yayitsrob the trump twostep on climate change say something kinda moderate do something extremely radical ',
#  'in race to curb climate change cities outpace governmentsparisagreement c globalcovenant citiesclimate',
#  'jellybeatles hey we have a new board for bouncing ideas on climate change are you interested ',
#  ' climatehome one week to save un cop climate change talks from trump  ',
#  ' businessinsider trump may end us lead in climate change and could make china great again  via guardian  ht',
#  ' aleszubajak in chile there is no space for climate denial because we see climate change threatening us in multiple shapes  ',
#  ' realdonaldtrump the concept of global warming was created by and for the chinese in order to make us manufacturing noncompetitive',
#  ' michaelawat so much denial so bad for us all energy depament climate office bans use of phrase climate change ',
#  'natural climate change wins manmade climate change     ',
#  'classicgrrl if no nuclear annihilation climate change will just kill us slowly',
#  ' weneedhillary cbs evening news donald trump put a global warming skeptic in charge of protecting the environment',
#  ' savingoceans wondering about climate change and how it impacts our oceans check out climatechange  with billnye ',
#  ' harmlessyarddog  kids aged  to  are suing the trump over climate change gtleftist are a disease ',
#  'how can man say we can stop global warming by putting our ac outside',
#  ' drbobbullard ãâëtheres no plan b climate change scientists fear consequence of trump victory  ',
#  ' francehillary trump is a chinese agent ignoring climate change and the benefits of clean energy only helps china weak',
#  'mashable  trump named a climate change denier to lead the agency that fights global warming  ',
#  ' kamalaharris proud to represent a state that is finding creative ways to act on climate change',
#  ' palmerrepo nodapl golden gate park joins badlands national park in defying donald trump by tweeting about climate change ',
#  'ineedtakeatwit zwash foxnews thejuanwilliams lolololololol oceans are rising even without climate change ',
#  'im just going to say that creationists that dont believe in global warming have never listened to bill nye',
#  'stand up for all of the successes of climate change',
#  ' fusion america is about to become the only country in the world with a leader who doesnt think global warming is real',
#  ' hayleiip someone told me im not qualified to discuss climate change so i pulled up a pic of my degree in environmental studies lol ni',
#  ' wingsscotland belfast alone probably accelerates global warming by a year in one night ',
#  'watching scott pruitt talk nonsense about global warming is raising my bp fool parisagreement',
#  'dicapriofdn why dont u preach global warming from your yacht hypocrite',
#  'if you havent watched this yet you really need to climate change is only going to get worse ',
#  'googlegirl  sues indian government over inaction on climate change   ',
#  ' ralphnoham the environment is facing its biggest opponent yet and its not climate changeits donald trump ',
#  ' followernodad parent id do anything for my childrenscientist heres how to stave off climate change so your children can stay o',
#  ' guardianeco how obamas climate change legacy is weakened by us investment in diy fuel ',
#  ' voxdotcom trumps election marks the end of any serious hope of limiting climate change to  degrees ',
#  'im sorry but if you think climate change is a hoax you are a fucking moron lol',
#  ' cineversitytv ff trumps corrupt epa chief says co isnt main cause of climate change fossil fuels are and  scoopit ',
#  ' sabrush trumps epa head says he does not believe carbon dioxide is the primary contributor to global warming ',
#  ' pablorodas climatechange p   trump picks climate change sceptic scott pruitt to lead epa  cop ',
#  ' gma arctic undergoing rapid ice melt that could speed global warming new study warns  ',
#  'gesemdicapt fuck global warming',
#  'anyone who lives on eah is laughing at all of this because climate change ',
#  ' vicenews trumps rumored pick to lead the epa wants everyone to ãâålove global warmingãâï  ',
#  'mattis also says that climate change is a problem just proves that elections are for show only ',
#  ' iansomerhalder speaking of climate changetonight is another killer episode of yearsofliving  c on natgeochannel ',
#  ' berniesanders the concept of global warming was created by and for the chinese in order to make us manufacturing noncompetiti',
#  ' per cent of climate scientists believe climate change is realdonaldtrump thinks its a chinese hoax sad ',
#  'epa head suggests co isnt a primary contributor to climate change  via engadget cmon',
#  ' sensanders we have a presidentelect who doesnt believe in climate change millions of people are going to have to say mr t',
#  'nhla suppos effos to combat climate change markmagana of nhlamember greenlatino latinopriorities ',
#  ' ddlovato ivotedbecause i believe in equality we need comprehensive immigration reform i am prochoice and global warming is real ',
#  'selling global warming as scientific vs governments control of everything by terrifying the public eahday ',
#  'the human magnitude of climate change looks more like a meteorite strike than a gradual change renewables crucia ',
#  ' brentsullivan climatehawk shell while they still deny climate change our denial that they could put profit over planet and people',
#  'sallykohn theyre related when pa of a larger pattern of change but that doesnt prove manmade climate change q is much do we affect',
#  ' joshgad the mourning stage is over now we fight putting a climate change denier as head of epa is an act of war on our kids standup',
#  ' un  globalgoals are directly linked to climate change the parisagreement is crucial to achieve them',
#  ' senfeinstein breaking senate appropriations committee just voted to restore vital funding for the un climate change panela big victo',
#  'epascottpruitt doesnt think co drives climate change lets send him a copy of global warming for dummies ',
#  ' ajplus top world leaders met at the g summit today all countries affirmed theyd fight climate change  except one can',
#  ' washingtonpost thanks to global warming antarctica is staing to turn green  ',
#  'its twelve in the am its bloody hot  as shit i cant go to sleep and now its fucking raining brought to you by global warming',
#  ' henningakesson interested in glaciers and climate change yr researcher position in regional climate modeling bjerknesbccr uib htt',
#  ' randomsavage frmatthewlc crazy how two days ago people were going bezerk about global warming then a blizzard hits',
#  'u of s opens water research facility to study climate change   climatechange',
#  ' katiewoh my story on the campaign to persuade every science teacher in the us that climate change is debatable frontlinepbs ',
#  ' michaelpielocik new york times new marquee hire denies climate change and previously wrote about the disease of the arab mind re',
#  'climate talks save us from global warming us urged bbcnews geographyteacher climatechange ',
#  ' timwattsmp i will not lead a pay that is not as committed to effective action on climate change as i am ',
#  ' nytimes as global warming cooks the us in the decades ahead not all states will suffer equally ',
#  'new cba case a warning step up on climate change or well see you in cou john hewson ',
#  'pope challenges un to fight climate change  via sdogbon mgwvjaiye ',
#  'isnt climate change just evolution for the planet if so why get upset about it or try to stop it who are we to make that call',
#  'you cannot come out right after a significant weather event and blindly blame it on climate change and still believe in science',
#  'new cba case a warning step up on climate change or well see you in cou  john hewson ',
#  'as the white house changes course on climate change california stubbornly presses forward ',
#  ' fastnewsdelhi science exhibition train to spread awareness on climate change sureshpprabhurailminindia ',
#  ' natgeochannel watch beforetheflood right here as leodicaprio travels the world to tackle climate change  htt',
#  'tahjshaunx funnymaine black men are the reason for global warming to her and hitlers main target in the holocaust was black women',
#  ' femalepains im gonna just ignore the fact that the world is either about to end bc of climate change or nuclear war and focus o',
#  ' manjusrii exxon trump putin amp  billion deal to accelerate global warming via mckenziewark  cc shoq ',
#  ' albestienstra climaterealists the almost  democrat vote of the very young is caused by climate change scaremongering and indoct',
#  'china drills tibet glaciers for climate change research',
#  'why morocco is leading the charge against climate change  cnn ',
#  ' ed slow progression of climate change my butt mother nature wants to be heard ',
#  'amcp the papers cridfxj  he will not sign up to the climate change agreement he has isolated himself completely we ',
#  ' is on track to be the hottest year on record but climate change is made up right',
#  ' elliehighwood ok so i am a crochet addict this is my global warming blanket stripes coloured according to last  years t an',
#  ' sierraclub potus just announced an ambitious but achievable plan to cut climate change pollution by  by  ',
#  ' adambandt anz today revealed they may not give mogages in future for houses impacted by sealevel rise from global warming ',
#  ' sensanders we can combat climate change at the local level joshfoxfilmand i are talking about how ',
#  'revkin  i got your point it is still stupid it is absurd to make every tornado hurricane etc result of man made climate change',
#  'ddentner tweetinjackleg tomseward stillgray you got it all wrong the person who called climate change a hoax is clearly the crazy one',
#  ' cudder everyone is enjoying this global warming',
#  ' sensanders we have a presidentelect who doesnt believe in climate change millions of people are going to have to say mr t',
#  ' msmwatchdog neoliberalism has conned us into fighting climate change as individuals  main lukacs ',
#  ' canadianpm thanks to georgesoros for sharing your insights on the global economic outlook and climate change davos wef ',
#  'for the first time on record humancaused climate change has rerouted an entire river ',
#  'epa chief doubts carbon dioxides role in global warming  bbc news ',
#  'a man who created a fake college okaya man who has no political experience okaya man who says global warming is by the chinese okay',
#  'iucnmed paicipating at environment amp climate change expeo group ufmsecretariat mediterranean ',
#  'why humans are so bad at thinking about climate change  via youtube',
#  ' makeinindia where the sun shines indias solar power commitment is a force against climate change worldbank makeinindia ',
#  ' cnn scientists are scrambling to protect research on climate change energized by concerns about trump administration ',
#  ' appolitics national park service defies white house social media ban tweets on climate change japanese interned during wwii ',
#  'pointedit climate change triggers the rise of giant orchids which battle giant carniverous plants to devour the dwindling humans thefilm',
#  ' snvworld decentralised renewables the front line against climate change  via powerall cop climateact',
#  'who is bringing the tornadoes and floods who is bringing the climate change god is after america he is plaguing her farrakhan quote',
#  'epa chief carbon dioxide not primary contributor to climate change ',
#  '  in the us write a letter to the editor urge media to connect the dots between climate change amp hurricane harvey',
#  'wisdom courage needed in climate change fight  sudbury star   climatechange',
#  'we may have even less time to stop global warming than we thought ',
#  ' janakilenin that is why we link rivers dive climate change funds to gst lay roads through forests etc ',
#  ' billnye just a little climate change whats a few billion here or there ',
#  'donald trump could put climate change on course for the danger zone ',
#  'if we have a nuclear war it might plunge us into a nuclear winter and then we wont have to worry about global warming',
#  ' sarahksilverman at what point in ur evolution did big oil make u realize climate change was a hoax ',
#  ' sierraclub weve doubled renewable energy production and become the leader in fighting climate change potus in philly climatevot',
#  ' anothergreen a kurdish response to climate change  ',
#  'rex tillerson may have used an alias to communicate with exxon officials about the risks of climate change ',
#  ' notlinkolafan i can fix climate change but you wont like it ',
#  ' lenajfc now the majority of people in office believe that climate change isnt real mother eah is mourning today',
#  'why are there people that deny the climate changenot that im mad or anything im just genuinely curious',
#  ' natgeochannel watch beforetheflood right here as leodicaprio travels the world to tackle climate change  htt',
#  'mrmcos probably right but had to challenge him given he doesnt know if climate change is real or not he should visit tuvalu kiribati',
#  'agriculture victim of and solution to climate change ',
#  ' independent us forces g to drop any mention of climate change in joint statement ',
#  'the depament of defense continues investment in cleanenergy and it has little to do with climate change ',
#  ' rowanjones so all we need to do is pay kimkardashian heaps of cash to promote climate change solutions lets do it people ',
#  'quebec municipalities to discuss climate change in montreal march  today  ',
#  ' environmentguru trump shifts stance on climate change  softeninghis tone on whether climate  climatechange',
#  ' natgeo by using projections from  models researchers predict how climate change threatens our water resources ',
#  'how climate change could kill punxsutawneyphil ',
#  ' moscowtimes russian astronomers complain that climate change is clouding their night skies realdonaldtrump you have ur order ',
#  ' wwfaustralia nsw landclearing laws a loss for action on climate change possingham  via radionational',
#  ' brentnyt but of course global warming is liberal hoax  ',
#  ' boredeaths if global warming doesnt exist then why is club penguin shutting down',
#  ' evacide the admin that puts a climate change denier in charge of the epa puts a guy who cant download his own apps in char',
#  ' mzjacobson extreme drought symptom of global warming enabled by fossil lobbyistspoliticians un  million may starve ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  ' cnn kids are taking the feds  and possibly trump  to cou over climate change ',
#  ' tulsigabbard we must continue to illustrate the impacts that climate change is already having on communities around the worldespecial',
#  ' johngal the top ten global warming skeptic arguments answered  dana nuccitelli  environment  the guardian ',
#  ' latimes harvey should be a warning to trump that climate change is a global threat  via',
#  'scientist spreads the word on climate change  by biking across america  wtop  via wtop',
#  ' ecolocyl epenvironment ceta contraries direction of our commitments to limit global warming below a temperature rise of c cetat',
#  ' sensanders we have a presidentelect who doesnt believe in climate change millions of people are going to have to say mr t',
#  ' igorbobic the sunday shows ignored a calamitous new global warming repo only show to mention snl ',
#  ' matthijs before the floodgreat documentary on the consequences of climate change with leonardo dicaprio ',
#  ' mtthwdvs if global warming doesnt exist then why is club penguin shutting down',
#  'trump is creating a void on climate change can california persuade other states to help fill it la times ',
#  'featuremexicos maya point way to slow species loss climate change ',
#  ' wfp did you know climate change can increase the risk of food insecurity and malnutrition  ',
#  'an old caoon of mine but just as relevant today as climate change denier scott pruitt works to subve the core ',
#  'every insane thing donald trump has said about global warming  ',
#  'i hope in  people finally learn the difference between global warming and climate change',
#  ' justintrudeau welcome to ottawa premiersilver  looking forward to working together to fight climate change amp protect our envi ',
#  'googleaction on climate change harmful unnecessary trump white house  green car repos ',
#  ' osmanakkoca i amosman akkoca declaring that if the countries want to stop climate change i am in turkey  epa  ',
#  'to deal with climate change we need a new financial system ',
#  'from heatwaves to hurricanes floods to famine seven climate change hotspots ',
#  'tnw scary interactive map shows how water levels will rise due to global warming ',
#  ' countermoonbat the people who predicted pas of manhattan would be underwater by  due to climate change are concerned about fake',
#  ' shellenbergermd new leodicaprio climate change web site attacks nuclear power while nuclear plant closures increase co emissions ht',
#  'grandma just said she doesnt believe in climate change lol',
#  ' danieljhannan people who accept the scientific consensus on climate change often dismiss the scientific consensus on say frackin',
#  'aveeuropathend pbp you cling to the idea that not having anything about civil rights or climate change on the website isnt the same',
#  'whosimmoal woh a watch and i believe it has sincere intentions but came off preachy to me someone who believes climate change',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  'the tomatoes are still fruiting and flowering in november mamas neighbour still thinks climate change is a lie ',
#  'thehill summarymillionaires and billionaires also global warming will kill us all',
#  ' guardiannews ãâëtheres no plan b climate change scientists fear consequence of trump victory  ',
#  'huntonweindorf explore climate changevillages in alaska woh a view regardless of stance on cc kttz making an impact texastech',
#  ' minhazmerchant g environment ministers meet in italy pledge to fight climate change as per paris accord with or without us',
#  ' democracynow chomsky on climate change every republican candidate either denied what is happening or said we shouldnt do a',
#  ' chunkymark true not all trump suppoers are white supremacist loving racist xenophobic climate change denying sexist swamp bigots ju',
#  'polar bear wild reindeer decline worsening as climate change continues to melt arctic ice abc ',
#  ' lsarsour the first  days of trump repealing obamacare dismantling executive orders amp flushing climate change in toilet ',
#  'thanks avery burdett for backing the environment a true storyfor common sense on climate change you can too at ',
#  ' pinklphants the mayor of chicago posted all of the climate change data that was deleted off the epas website under trump on the city',
#  ' slate politicians wont tackle climate change should we call it something else  ',
#  ' winenewz the wine industry in europe could be in trouble due to global warming researchers warn ',
#  'ty lorealusa nytimes its not called global warming  its called climate change amp yes its real but i gu ',
#  ' sensanders we have a presidentelect who doesnt believe in climate change thats frightening for this country and the world',
#  'trump really doesnt want to face these  kids on climate change  ',
#  ' aggyk five pacific islands lost to rising seas as climate change hits ',
#  'nasa is defiantly communicating climate change science despite trumps doubts   nasaclimate lift em up yall',
#  ' plesscatherine team energyclimate change we should check this out mcggovt mariamamcg cocodupepe marlapeyre eliseffant ',
#  'talk about it when you believe in something especially climate change because we need to know that we arent alon ',
#  ' pollrepo to address climate change us isdoing enough doing too much needs to do more quinnipiac u rv ',
# ...
#  ' billmckibben massive algae blooms in the arabian sea tied to climate changein oxygenchoked waters beneath fish die ',
#  ' chinasolar as eah gets hotter scientists break new ground linking climate change to extreme weather  scien',
#  ' cnazmul staing of synthesizing  repos on community climate change projects of pksf saleemulhuq gobeshona icccad ',
#  ' bramnessellen we need to tap into the science base to enable insurance to fill its role in handling climate change finnor at insconf',
#  'without action on climate change say goodbye to polar bears  by petterstordalen via cnvey',
#  ' climatehawk from heatwaves to hurricanes floods to famine  climate change hotspots  johnvidal guardian',
#  ' stellaaaar here in the us you got rich white dudes saying what global warming and the world is starving and dying as a result of',
#  'morocco launches triple a initiative to challenge climate change ',
#  ' spsr removing the funding source for the pipeline nuclear chain and other climate change issues is an effective tool ',
#  ' guardian conservatives elected trump now they own climate change  john abraham ',
#  'peru builds up wetland resilience to reinforce indigenous response to climate change  ',
#  ' izhaaremuzamat kp is fighting climate change transformed hospital reformed police amp lb system amp yet making infrastructure projectsa',
#  ' chancedavies as a proud wildroser i believe climate change is a authentic threat to humanity and requires action from my fellow cons',
#  'the us republican spreading the conservative case for acting on climate change ',
#  'germany california to tackle climate change together  reuters demforce ',
#  ' jennmperron this is so vermont love it a vermont nature diary documents downtoeah signs of climate change boston globe ',
#  ' buggwen read this fantastic piece on teaching kids climate change in conservative districts by amyharmon ',
#  'but if climate change is real how come theres still many liberal snowflakes scienceisntreal am i tomi lahren yet  ',
#  'bryanjfischer seems like its not a very complete analysis on climate change globally to only look at one spot how about global sea ice',
#  'cnn either we end our contribution to climate change or climate change will continue until its powerful enough to ',
#  ' cbcnews trump win a disaster in the fight against climate change scientists and environmentalists say',
#  ' gabaker trumps kids know climate change is real and humancaused lets hope he listens to them',
#  ' janpaulvansoest another us agency deletes references to climate change on government website ',
#  ' jpvanypersele the limit to fossil fuel usage is climate change not the socalled peak fossil fuel in availability ',
#  'doe head says carbon dioxide not primary cause of climate change   climatechange',
#  ' uspgglobal our annual bray day service named after our founder will focus on climate change wed  feb am london ',
#  ' realdonaldtrump the concept of global warming was created by and for the chinese in order to make us manufacturing noncompetitive',
#  'sinow sipetethamel i guess global warming and sea rise came earlier than i thought now that wichita is on the atlantic coast',
#  ' astrokatie in case you were wondering no  years of usled inaction on climate change will not go well for the planet now is when i',
#  'while trumps team denies climate change cities and states are fighting back ',
#  'climate change is here and realsaibai island is in same predicament as boigu both muddy amp inundated ',
#  ' bbcscotlandnews santa might need extra reindeer to pull his sleigh due to effects of climate change   ',
#  'white house calls climate change funding a waste of your money  video  dsnworld',
#  'despite climate change exodus some marshall islanders head back home',
#  'fight against climate change finds an unlikely ally donald trump ',
#  'bharren so youre down with him denying climate change is real amp wants to stop funding un climate change effos makessense',
#  'spended da day servicing da snowblowers in sho sleeves outside da bright side of climate change',
#  ' conradknauer the most effective political arguments for taking climate change seriously arent ones that simply rest on the',
#  ' cernovich same expes who said hillary would win claim climate change is real lol go away morons you know nothing and you los',
#  ' veganiaa the good news about climate change is that we can curb it just by living veganclimate deforestation meat dairy',
#  ' ccities fumiko hayashi mayor of yokohama is a model leader fighting climate change womenclimate ',
#  'opinion  new york times editor pens weak vague response to critics of bret stephenss oped on climate change ',
#  'weather channel blasts at trump aide over climate change ',
#  'njsurekha or this shows who was already united on this issue and who doesnt see long term value in mitigating climate change',
#  'whoabrorelax hence something like climate change findings',
#  'does your dad really believe that climate change is a hoax or can he be cwant to destroy the world climate',
#  ' berniesanders there can be no compromise on the issue of climate change which is a threat to the entire planet ',
#  ' sirwilfreddeath alicewoolley bonnegreer bbc gives false equivalence to so many arguments from politics to climate change in eff',
#  ' nytimes opinion trump is in charge at a critical moment for keeping climate change in check we may never recover ',
#  'what do you guys think of trumps stance on climate change and global warming  ',
#  ' marinbray how is everyone so calm about climate change i think about it for  seconds and become rationally angry',
#  ' pwihub the un gave australia a poor score for climate change progress it hasnt created adequate climate change policy ',
#  ' assaadrazzouk in the new new world china lectures the united states about climate change and the impoance of cooperation betwe',
#  ' sciam polling suggests that americans have sharply different opinions on climate change than the president ',
#  ' sensanders algore continues to educate people around the world on the planetary crisis of climate change we thank him so mu',
#  ' sarahkendzior first he asked for list of people who believe in climate change and womens rights but now antiterrorism expes',
#  'rex tillerson grilled on exxonmobil conflicts russia sanctions and climate change at senate confirmation hearing ',
#  'the word on global warming its happening its arrived ',
#  ' worldfnature air pollution deaths expected to rise because of climate change  cbs news  ',
#  ' stephenschlegel shes thinking about how shes going to die because your husband doesnt believe in climate change ',
#  ' cassandrasweet energy dept rejects trumps request to name climate change workers who remain worried ',
#  ' ukipnfkn we now have a climate change sceptic in charge of environment a man who hates europe in charge of brexit an nhs  ',
#  ' mmurraypolitics the debate over climate change and global warming is far from settled he wrote in that may  piece ',
#  'eiffel tower lit green in honor of paris climate change deal  ',
#  ' mrozatheist leonardo dicaprio met with donald trump to discuss climate change maybe at some stage some scientists will be involve',
#  ' fusion america is about to become the only country in the world with a leader who doesnt think global warming is real',
#  'donald trump set to visit france for bastille day macron will bring up climate change trade issues ',
#  'premierbradwall i think justintrudeau is buying on the gullibility of canadians regarding climate change',
#  ' dailynewsegypt g stage set for climate change showdown   ',
#  'us energy depament balks at trumps request for the names of those who worked on climate change ',
#  ' sbeattiesmith stark research shows humid heatwaves will kill s of s if climate change is left unchecked good news is we can',
#  ' slate trump will be the only world leader to deny climate change  ',
#  'can biochar make climate change a profitable business oppounity  via ecobusinesscom',
#  ' aiannucci the us elected trump but the rest of the world didntso what do we do if us policies  eg climate change threaten the re',
#  'some r advocating a special role for central banksusing a range of instruments climate changerelated discl ',
#  'chemists find that spoiling series causes global warming',
#  ' sethmacfarlane hrc proposes installing half a billion solar panels by the end of her first term trump thinks climate change is a hoax',
#  ' eldobleem any scientist out there still want to defend climate change both hoax inventors have runok lets focus on pic',
#  ' allenwest bless her hea chelsea clinton wades into the climate change debate on twitter it instantly backfires',
#  ' foeus exxonknew of the many risks of climate change and still spent years actively distoing the truth',
#  'wired media already accused of missing the boat with the american electorate cool it with the harping climate change trump predictions',
#  ' belugasolar donald trumps attitude towards climate change will cost american taxpayers billions vie independent',
#  ' thehill federal cou shuts down governmentapproved pipeline project over climate change concerns  ',
#  'buylottery do you experience any effects of global warming there overclock you indeed i think i got a stain on my diodes annealing new in',
#  'tuesdaythoughtsdo or die save humanity amp save  can be warriors against climate change ',
#  ' senatormenendez retweet if you think this climate change repo needs to be seen we cant let the trump administration ignore it htt',
#  ' sustainablerein we must work to elect representatives who believe in climate change and are willing to act ',
#  'independent so climate change rapes women wtf are you people insane no criminals do that the media today has some serious mental issues',
#  ' jackcushmanjr as gettleman notes those hit hardest by climate change bear least blame  not just  famine but  ',
#  ' pscotlandcsg together  commonwealth countries can help reverse damaging impactexistential threat of climate change adopting r',
#  'i asked chance for a glass of water and he said omg youre freaking liberal you know global warming is making us run out of water ',
#  ' brendannyhan conservatives will accept the scientific facts of climate change when conservative elites signal that thats what',
#  ' deanofcomedy hey trumpi dare you go to texas while people are suffering from hurricane and tell them ur view climate change is a hoax',
#  'shell knew oil giants  film warned of climate change danger ',
#  'we hear a lot about coal and climate change what about greenhouse gas emissions from intensive animal ag climatechange environment',
#  ' robsilver to be clear any premier fighting climate change kevin oleary is coming after you a senator poo pooing residen',
#  ' leohickman theresa mays new chief of staff gavin barwell is known for his knowledgable concern about climate change ',
#  ' motherjones look at all the climate change deniers vying for jobs in the trump administration  ',
#  ' defenders icymi scott pruitt says carbon dioxide not a major cause of global warming  actonclimate ',
#  'finally paris climate change agreement designed by crooks trump is not buying this crap ',
#  'axelmannsays scaredycat hollinsmrhump you may not agree with climate change axel but i believe you have some left leanings yourself ',
#  ' hallamstaff find out about global goals a series of targets to end povey and tackle climate change at this event on  may',
#  'if global warming doesnt scare you andor you dont care about it boo bye',
#  ' trevorghouser in the us climate change has never experienced the level of media attention or public interest it received over th',
#  ' spectatorindex breaking white house website has removed climate change lgbt rights and healthcare from its issues section',
#  ' stopadanicairns you will destroy all thus effo unless you stopadani c global warming will kill the coral joshfrydenberg',
#  ' cnni no snow where there should be bleached anemones cracks in the ice this is what climate change looks like',
#  'we can chose to be on the right side of history on climate change or we can be catastrophically wrong its real a ',
#  'i just joined natgeochannel cf in combating climate change take action beforetheflood ',
#  'tbh people who believe climate change isnt real are the ones that need free education the most',
#  ' thehill sanders rips trumps epa pick for saying his personal opinion on climate change is immaterial',
#  ' julianburnside hey turnbullmalcolm heres a tip for climate change etc what about being a leader isnt that your jobaustralia nee',
#  ' cnn no snow where there should be bleached anemones cracks in the ice this is what climate change looks like',
#  ' ericholthaus be wary of those that caution against politicizing harvey our choicesdevelopment social suppos climate changea',
#  'realdonaldtrump would you like me to delete my knowledge of climate change too climatechangeisreal',
#  'ohhh i bet if lady libey could cry we could forget blaming global warming for a rise in sea levels ',
#  'failure to act now to make our food systems more resilient to climate change will seriously compromise food ',
#  ' antaisce for many cold adapted species ravaged by decades of habitat loss amp degredation climate change is a bridge too far ',
#  ' bwecht just your daily reminder that scientific evidence overwhelmingly indicates that humanmade climate change is real',
#  ' tomilahren how to anger a conservative hu american jobs how to anger a liberal insult the climate change crusade ',
#  ' cracked so glad gore and trump could find some middle ground between global warming is real and its a chinese hoax designed to des',
#  ' sensanders we have a presidentelect who doesnt believe in climate change thats frightening for this country and the world',
#  ' iansomerhalder speaking of climate changetonight is another killer episode of yearsofliving  c on natgeochannel ',
#  'retweetnew pentagon chief says climate change threatens security ',
#  'this photographer is documenting the unparalleled beautyand effects of climate changein americas national parks ',
#  'im jealous of the winter storm on the east coast and sad about mn temps expected to be in the s today glad global warming isnt real',
#  'boyheboutto i wish i could be there im listening to two vets talk about how climate change is a hoax but ufos are real im very amused',
#  ' brookingsinst heres the damage trump could realistically do to global climate change agreements  ',
#  ' drshaena why am i out here tweeting about climate change with my real name and face on everything but every hateful reply is anonymo',
#  ' niatrump climatechange for  trillion al gore will save the eah from what tho global warming ice age or the fatties',
#  'johnkerry climate change is bullshit cofounder of greenpeace even said he was wrong its the suns activity you f ',
#  ' socialism neoliberalism has conned us into fighting climate change as individuals ',
#  'finally done with the uncc introductory ecourse on climate changethanks unitar uncclearn climateducate',
#  'a high of  today the first day of november yep global warming is fake',
#  ' bloombergdotorg climateofhope is a call to action for cities where climate change is the harshest and solutions are most promisin',
#  ' notarealnun please dont vote for the guy who doesnt believe in climate change views women as objects and has an overall lack of jus',
#  'population growth plus climate change equals disaster  the heraldtimes subscription ',
#  ' jimwitkins trump fools the new york times on climate change by climateprogress  actonclimate',
#  ' natgeochannel watch beforetheflood right here as leodicaprio travels the world to tackle climate change  htt',
#  'what do satellites tell us about climate change  via youtube',
#  ' richardbranson tackling climate change by changing the shipping trucking aviation and mining industries  htt',
#  ' dyechai the snow is coming or not global warming ',
#  'lourollx teenvogue good call with so many people fighting against the idea that climate change is real we need people like you helping',
#  ...]

# %%
train_df['message'] = punc_removed

# %%
train_df.head()
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  polyscimajor epa chief doesnt think carbon dio...   625221
# 1          1  its not like we lack evidence of anthropogenic...   126103
# 2          2   rawstory researchers say we have three years ...   698562
# 3          1  todayinmaker wired   was a pivotal year in the...   573736
# 4          1   soynoviodetodas its  and a racist sexist clim...   466954
#
#                                               tokens
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [its, not, like, we, lack, evidence, of, anthr...
# 2  [rt, rawstory, researchers, say, we, have, thr...
# 3  [todayinmaker, wired, 2016, was, a, pivotal, y...
# 4  [rt, soynoviodetodas, its, 2016, and, a, racis...

# %%
# define stemmer function
stemmer = SnowballStemmer('english')

# tokenise data
tokeniser = TreebankWordTokenizer()
tokens=[]
for i in train_df['message']:
    tokens.append(tokeniser.tokenize(i))

# define lemmatiser
lemmatizer = WordNetLemmatizer()

# %%
train_df['tokens'] = tokens

# %%
train_df.head(100)
# Out:
#     sentiment                                            message  tweetid  \
# 0           1  polyscimajor epa chief doesnt think carbon dio...   625221
# 1           1  its not like we lack evidence of anthropogenic...   126103
# 2           2   rawstory researchers say we have three years ...   698562
# 3           1  todayinmaker wired   was a pivotal year in the...   573736
# 4           1   soynoviodetodas its  and a racist sexist clim...   466954
# ..        ...                                                ...      ...
# 95          1   ronaldklain as trump decides on paris briancd...   458845
# 96          1   savingoceans lack of climate change action ca...   695439
# 97          1  yet another trump advisor is clueless on clima...   894382
# 98          1   stephenschlegel shes thinking about how shes ...   603318
# 99          2  us environmental agency chief says humans cont...   554354
#
#                                                tokens
# 0   [polyscimajor, epa, chief, doesnt, think, carb...
# 1   [its, not, like, we, lack, evidence, of, anthr...
# 2   [rawstory, researchers, say, we, have, three, ...
# 3   [todayinmaker, wired, was, a, pivotal, year, i...
# 4   [soynoviodetodas, its, and, a, racist, sexist,...
# ..                                                ...
# 95  [ronaldklain, as, trump, decides, on, paris, b...
# 96  [savingoceans, lack, of, climate, change, acti...
# 97  [yet, another, trump, advisor, is, clueless, o...
# 98  [stephenschlegel, shes, thinking, about, how, ...
# 99  [us, environmental, agency, chief, says, human...
#
# [100 rows x 4 columns]

# %%
# remove stopwords
tokens_less_stopwords = [word for i in train_df['tokens'] for word in i if len(word) > 2 if word not in stopwords.words('english')]

# %%
tokens_less_stopwords
# Out:
# ['polyscimajor',
#  'epa',
#  'chief',
#  'doesnt',
#  'think',
#  'carbon',
#  'dioxide',
#  'main',
#  'cause',
#  'global',
#  'warming',
#  'wait',
#  'via',
#  'mashable',
#  'like',
#  'lack',
#  'evidence',
#  'anthropogenic',
#  'global',
#  'warming',
#  'rawstory',
#  'researchers',
#  'say',
#  'three',
#  'years',
#  'act',
#  'climate',
#  'change',
#  'late',
#  'todayinmaker',
#  'wired',
#  'pivotal',
#  'year',
#  'war',
#  'climate',
#  'change',
#  'soynoviodetodas',
#  'racist',
#  'sexist',
#  'climate',
#  'change',
#  'denying',
#  'bigot',
#  'leading',
#  'polls',
#  'electionnight',
#  'woh',
#  'read',
#  'whether',
#  'dont',
#  'believe',
#  'climate',
#  'change',
#  'thenation',
#  'mike',
#  'pence',
#  'doesnt',
#  'believe',
#  'global',
#  'warming',
#  'smoking',
#  'causes',
#  'lung',
#  'cancer',
#  'makeandmendlife',
#  'six',
#  'big',
#  'things',
#  'today',
#  'fight',
#  'climate',
#  'change',
#  'climate',
#  'activist',
#  'aceofspadeshq',
#  'nephew',
#  'inconsolable',
#  'wants',
#  'die',
#  'old',
#  'age',
#  'like',
#  'perish',
#  'fiery',
#  'hellscape',
#  'climate',
#  'change',
#  'paigetweedy',
#  'offense',
#  'like',
#  'believe',
#  'global',
#  'warming',
#  'stephenschlegel',
#  'shes',
#  'thinking',
#  'shes',
#  'going',
#  'die',
#  'husband',
#  'doesnt',
#  'believe',
#  'climate',
#  'change',
#  'hope',
#  'people',
#  'vocal',
#  'climate',
#  'change',
#  'also',
#  'powering',
#  'homes',
#  'renewable',
#  'energy',
#  'like',
#  'goodenergy',
#  'tveitdal',
#  'percent',
#  'chance',
#  'avoiding',
#  'dangerous',
#  'global',
#  'warming',
#  'study',
#  'finds',
#  'alifaith',
#  'godtrumps',
#  'government',
#  'removes',
#  'climate',
#  'change',
#  'page',
#  'epa',
#  'website',
#  'hours',
#  'ahead',
#  'climatemarch',
#  'fossil',
#  'fuel',
#  'giant',
#  'exxonmobil',
#  'misled',
#  'public',
#  'climate',
#  'change',
#  'harvard',
#  'academics',
#  'conclude',
#  'glblctzn',
#  'dont',
#  'wan',
#  'live',
#  'forever',
#  'nothing',
#  'climate',
#  'change',
#  'taylorswift',
#  'zaynmalik',
#  'jackholmes',
#  'issues',
#  'scrubbed',
#  'today',
#  'civil',
#  'rights',
#  'climate',
#  'change',
#  'lgbt',
#  'healthcare',
#  'patagonia',
#  'elected',
#  'leaders',
#  'fail',
#  'approach',
#  'environment',
#  'amp',
#  'climate',
#  'change',
#  'serious',
#  'issues',
#  'wohy',
#  'urgency',
#  'amp',
#  'action',
#  'sensanders',
#  'presidentelect',
#  'doesnt',
#  'believe',
#  'climate',
#  'change',
#  'millions',
#  'people',
#  'going',
#  'say',
#  'calum',
#  'tweets',
#  'abt',
#  'reunitingish',
#  'castsees',
#  'replies',
#  'begging',
#  'come',
#  'countriescalum',
#  'goes',
#  'back',
#  'ing',
#  'climate',
#  'change',
#  'ccities',
#  'mayors',
#  'representing',
#  'citizens',
#  'urged',
#  'leaders',
#  'saveourplanet',
#  'climate',
#  'change',
#  'worldwildlife',
#  'climate',
#  'change',
#  'impacts',
#  'wildlife',
#  'cop',
#  'eahtomarrakech',
#  'also',
#  'met',
#  'guy',
#  'let',
#  'truth',
#  'climate',
#  'change',
#  'gay',
#  'people',
#  'existing',
#  'scientists',
#  'say',
#  'climate',
#  'change',
#  'wiped',
#  'entire',
#  'underwater',
#  'ecosystem',
#  'againclimate',
#  'tammygrubb',
#  'obama',
#  'raises',
#  'climate',
#  'change',
#  'better',
#  'vote',
#  'candidates',
#  'believe',
#  'science',
#  'obamaunc',
#  'hate',
#  'say',
#  'mental',
#  'health',
#  'pretty',
#  'low',
#  'menu',
#  'climate',
#  'change',
#  'hits',
#  'food',
#  'production',
#  'bangladesh',
#  'confronting',
#  'climate',
#  'change',
#  'head',
#  'hey',
#  'michaels',
#  'vetted',
#  'approved',
#  'marketbased',
#  'strategies',
#  'tackling',
#  'climate',
#  'change',
#  'suppoed',
#  'majority',
#  'cdns',
#  'cdnpoli',
#  'sally',
#  'kohns',
#  'latest',
#  'evidence',
#  'climate',
#  'change',
#  'proves',
#  'sma',
#  'person',
#  'via',
#  'twitchyteam',
#  'need',
#  'say',
#  'staalkradio',
#  'first',
#  'public',
#  'understands',
#  'climate',
#  'change',
#  'better',
#  'congress',
#  'johnholdren',
#  'corybooker',
#  'neiltyson',
#  'explain',
#  'htt',
#  'jnpftw',
#  'scientists',
#  'denounce',
#  'climate',
#  'change',
#  'choice',
#  'honey',
#  'guide',
#  'global',
#  'warming',
#  'paris',
#  'pact',
#  'role',
#  'demforce',
#  'theresistance',
#  'uniteblue',
#  'latimes',
#  'atmospheric',
#  'rivers',
#  'fueled',
#  'climate',
#  'change',
#  'could',
#  'decimate',
#  'wild',
#  'oysters',
#  'san',
#  'francisco',
#  'bay',
#  'denying',
#  'climate',
#  'change',
#  'ignores',
#  'basic',
#  'science',
#  'bgr',
#  'china',
#  'practically',
#  'says',
#  'trump',
#  'lied',
#  'climate',
#  'change',
#  'berniesanders',
#  'imvotingbecause',
#  'future',
#  'planet',
#  'stake',
#  'hillary',
#  'clinton',
#  'combat',
#  'climate',
#  'change',
#  'donald',
#  'trump',
#  'thinks',
#  'independent',
#  'trumps',
#  'team',
#  'removed',
#  'climate',
#  'change',
#  'data',
#  'white',
#  'house',
#  'website',
#  'may',
#  'breaking',
#  'law',
#  'deboraheha',
#  'toxic',
#  'soils',
#  'aquifers',
#  'vast',
#  'amts',
#  'wasted',
#  'waste',
#  'water',
#  'runaway',
#  'climate',
#  'change',
#  'gas',
#  'fracking',
#  'bettybowers',
#  'america',
#  'climate',
#  'change',
#  'unproven',
#  'people',
#  'sure',
#  'guy',
#  'called',
#  'noah',
#  'fit',
#  'worlds',
#  'animals',
#  'dealt',
#  'simple',
#  'issues',
#  'like',
#  'climate',
#  'change',
#  'energy',
#  'policy',
#  'complex',
#  'issues',
#  'mal',
#  'tones',
#  'qanda',
#  'foramerica',
#  'protested',
#  'suppo',
#  'climate',
#  'change',
#  'womansmarch',
#  'help',
#  'environment',
#  'climate',
#  'targets',
#  'nations',
#  'playing',
#  'long',
#  'game',
#  'fighting',
#  'global',
#  'warming',
#  'via',
#  'conversationedu',
#  'thedailybeast',
#  'trumps',
#  'climate',
#  'change',
#  'denial',
#  'could',
#  'cost',
#  'trillion',
#  'andrewsharp',
#  'win',
#  'probability',
#  'bullshit',
#  'man',
#  'saw',
#  'nba',
#  'finals',
#  'thats',
#  'knew',
#  'global',
#  'warming',
#  'isnt',
#  'real',
#  'washingtonpost',
#  'alaskan',
#  'tundra',
#  'filling',
#  'atmosphere',
#  'carbon',
#  'dioxide',
#  'worsening',
#  'climate',
#  'change',
#  'thetorontosun',
#  'sunlorrie',
#  'indian',
#  'environmentalist',
#  'calls',
#  'dicaprio',
#  'documentary',
#  'climate',
#  'change',
#  'realdonaldtrump',
#  'carbon',
#  'tax',
#  'globalist',
#  'idea',
#  'enslave',
#  'worlds',
#  'population',
#  'whole',
#  'reason',
#  'propagating',
#  'global',
#  'warming',
#  'anyone',
#  'suppos',
#  'trumps',
#  'view',
#  'climate',
#  'change',
#  'non',
#  'polluter',
#  'cronie',
#  'please',
#  'step',
#  'forward',
#  'resist',
#  'impeach',
#  'stevesgoddard',
#  'winds',
#  'close',
#  'mph',
#  'area',
#  'afternoon',
#  'would',
#  'blame',
#  'climate',
#  'change',
#  'except',
#  'happens',
#  'starbuck',
#  'world',
#  'food',
#  'supplies',
#  'risk',
#  'climate',
#  'change',
#  'threatens',
#  'international',
#  'trade',
#  'warn',
#  'expes',
#  'foxnews',
#  'macron',
#  'charm',
#  'may',
#  'changed',
#  'trumps',
#  'mind',
#  'climate',
#  'change',
#  'stephenschlegel',
#  'shes',
#  'thinking',
#  'shes',
#  'going',
#  'die',
#  'husband',
#  'doesnt',
#  'believe',
#  'climate',
#  'change',
#  'chris',
#  'initially',
#  'talked',
#  'climate',
#  'changeme',
#  'thinked',
#  'three',
#  'seconds',
#  'europea',
#  'approve',
#  'executive',
#  'order',
#  'realdonaldtrump',
#  'due',
#  'sign',
#  'climate',
#  'change',
#  'environment',
#  'trump',
#  'doesnt',
#  'believe',
#  'global',
#  'warming',
#  'hes',
#  'going',
#  'president',
#  'united',
#  'states',
#  'america',
#  'fuck',
#  'kelkulus',
#  'irony',
#  'florida',
#  'state',
#  'danger',
#  'washed',
#  'away',
#  'due',
#  'rising',
#  'sea',
#  'levels',
#  'elected',
#  'guy',
#  'denies',
#  'climate',
#  'change',
#  'misslizzynj',
#  'lmao',
#  'snowflakes',
#  'complaining',
#  'snowflakes',
#  'winter',
#  'global',
#  'warming',
#  'dawndawn',
#  'one',
#  'arnold',
#  'schwarzeneggers',
#  'vehicles',
#  'whining',
#  'climate',
#  'changehows',
#  'maidillegal',
#  'orhttp',
#  'glennf',
#  'calling',
#  'great',
#  'space',
#  'cylinder',
#  'save',
#  'global',
#  'warming',
#  'greenpeaceeasia',
#  'pollution',
#  'india',
#  'china',
#  'reached',
#  'stratosphere',
#  'could',
#  'speed',
#  'global',
#  'warming',
#  'unep',
#  'citiesclimfin',
#  'lays',
#  'cities',
#  'subnational',
#  'bodies',
#  'finance',
#  'solutions',
#  'climate',
#  'change',
#  'house',
#  'republicans',
#  'say',
#  'climate',
#  'change',
#  'real',
#  'time',
#  'fight',
#  'ninaburleigh',
#  'global',
#  'warming',
#  'hoax',
#  'though',
#  'kylegriffin',
#  'nyt',
#  'reviewed',
#  'draft',
#  'climate',
#  'change',
#  'rpt',
#  'fed',
#  'scientists',
#  'directly',
#  'contradicting',
#  'admins',
#  'global',
#  'warming',
#  'claims',
#  'fuckofflaine',
#  'jjxrry',
#  'spacex',
#  'quebanjesus',
#  'antarctica',
#  'big',
#  'lmao',
#  'global',
#  'warming',
#  'real',
#  'like',
#  'nigga',
#  'use',
#  'air',
#  'conditioner',
#  'two',
#  'cents',
#  'global',
#  'political',
#  'leadership',
#  'climate',
#  'change',
#  'trump',
#  'era',
#  'bbcbreaking',
#  'government',
#  'signs',
#  'paris',
#  'agreement',
#  'worlds',
#  'first',
#  'comprehensive',
#  'treaty',
#  'tackling',
#  'climate',
#  'change',
#  'hope',
#  'china',
#  'tells',
#  'trump',
#  'climate',
#  'change',
#  'isnt',
#  'hoax',
#  'invented',
#  'via',
#  'business',
#  'lol',
#  'china',
#  'schooling',
#  'motherjones',
#  'races',
#  'watch',
#  'care',
#  'global',
#  'warming',
#  'uscgpacificnw',
#  'nsf',
#  'icebreaking',
#  'ships',
#  'primary',
#  'cause',
#  'climate',
#  'change',
#  'let',
#  'arctic',
#  'freeze',
#  'amp',
#  'stay',
#  'away',
#  'kelkulus',
#  'irony',
#  'florida',
#  'state',
#  'danger',
#  'washed',
#  'away',
#  'due',
#  'rising',
#  'sea',
#  'levels',
#  'elected',
#  'guy',
#  'denies',
#  'climate',
#  'change',
#  'global',
#  'warming',
#  'doesnt',
#  'exist',
#  'club',
#  'penguin',
#  'shutting',
#  'profpcdohey',
#  'need',
#  'economists',
#  'incorporate',
#  'reality',
#  'climate',
#  'change',
#  'thinking',
#  'amp',
#  'need',
#  'listen',
#  'ushrn',
#  'fight',
#  'human',
#  'rights',
#  'also',
#  'facing',
#  'disastrous',
#  'impacts',
#  'climate',
#  'change',
#  'cernovich',
#  'climate',
#  'change',
#  'real',
#  'ahamiltonspirit',
#  'question',
#  'climate',
#  'change',
#  'manmade',
#  'doubts',
#  'havent',
#  'seen',
#  'inconvenient',
#  'truth',
#  'please',
#  'alphageekstr',
#  'process',
#  'climate',
#  'change',
#  'occurs',
#  'naturally',
#  'extreme',
#  'levels',
#  'well',
#  'eventually',
#  'severe',
#  'droughts',
#  'roschneider',
#  'neoliberalism',
#  'conned',
#  'fighting',
#  'climate',
#  'change',
#  'individuals',
#  'main',
#  'lukacs',
#  'davidsirota',
#  'must',
#  'read',
#  'rick',
#  'perry',
#  'ordered',
#  'texas',
#  'legislature',
#  'kill',
#  'bill',
#  'requiring',
#  'state',
#  'agencies',
#  'prepare',
#  'climate',
#  'change',
#  'sensanders',
#  'presidentelect',
#  'doesnt',
#  'believe',
#  'climate',
#  'change',
#  'thats',
#  'frightening',
#  'country',
#  'world',
#  'hot',
#  'due',
#  'global',
#  'warming',
#  'ldnenvironment',
#  'weve',
#  'sho',
#  'term',
#  'opps',
#  'working',
#  'climate',
#  'change',
#  'amp',
#  'energy',
#  'send',
#  'environmentlondongovuk',
#  'markbaileymp',
#  'fed',
#  'energyenvt',
#  'minister',
#  'joshfrydenberg',
#  'refused',
#  'allow',
#  'term',
#  'climate',
#  'change',
#  'coag',
#  'energy',
#  'council',
#  'communique',
#  'despit',
#  'jadorelacouture',
#  'fact',
#  'leonardo',
#  'dicaprio',
#  'met',
#  'trump',
#  'discuss',
#  'climate',
#  'change',
#  'man',
#  'verge',
#  'google',
#  'eahs',
#  'timelapse',
#  'update',
#  'illustrates',
#  'years',
#  'climate',
#  'change',
#  'sethmacfarlane',
#  'hrc',
#  'proposes',
#  'installing',
#  'half',
#  'billion',
#  'solar',
#  'panels',
#  'end',
#  'first',
#  'term',
#  'trump',
#  'thinks',
#  'climate',
#  'change',
#  'hoax',
#  'beforetheflood',
#  'everyone',
#  'must',
#  'watch',
#  'people',
#  'must',
#  'understand',
#  'global',
#  'warming',
#  'real',
#  'leodicaprio',
#  'doesnt',
#  'shake',
#  'climate',
#  'change',
#  'nothing',
#  'ever',
#  'smithsonianenv',
#  'sercs',
#  'roy',
#  'rich',
#  'amp',
#  'colleagues',
#  'create',
#  'buzz',
#  'germany',
#  'global',
#  'warming',
#  'simulation',
#  'eahjustice',
#  'noaa',
#  'repo',
#  'hottest',
#  'year',
#  'history',
#  'one',
#  'reason',
#  'fight',
#  'climate',
#  'change',
#  'deniers',
#  'trump',
#  'admin',
#  'conservatives',
#  'love',
#  'denying',
#  'science',
#  'huh',
#  'climate',
#  'change',
#  'believing',
#  'feilization',
#  'egg',
#  'automatic',
#  'human',
#  'life',
#  'senior',
#  'air',
#  'quality',
#  'climate',
#  'change',
#  'specialist',
#  'senior',
#  'air',
#  'airquality',
#  'climatechange',
#  'greenhousegas',
#  'come',
#  'check',
#  'events',
#  'climate',
#  'change',
#  'srhpl',
#  'think',
#  'million',
#  'could',
#  'gone',
#  'towards',
#  'alleviating',
#  'povey',
#  'reducing',
#  'climate',
#  'change',
#  'improving',
#  'healthcare',
#  'call',
#  'mad',
#  'cnn',
#  'protest',
#  ...]

# %% [markdown]
# Split x and y variable from the train dataset:

# %%
X = train_df['tokens']
y = train_df['sentiment']

# %%
from imblearn.over_sampling import SMOTE 
smt=SMOTE()
X_train_sm, y_train_sm = smt.fit_resample(X_train, y_train)

# %% [markdown]
# Make the text readable for the model:

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=2, stop_words="english")
X_vectorized = vectorizer.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-45e9961de3d3> in <module>
#       1 vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=2, stop_words="english")
# ----> 2 X_vectorized = vectorizer.fit_transform(X)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1650         """
#    1651         self._check_params()
# -> 1652         X = super().fit_transform(raw_documents)
#    1653         self._tfidf.fit(X)
#    1654         # X is already a transformed view of raw_documents so
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     968         for doc in raw_documents:
#     969             feature_counter = {}
# --> 970             for feature in analyze(doc):
#     971                 try:
#     972                     feature_idx = vocabulary[feature]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     350                                                tokenize)
#     351             return lambda doc: self._word_ngrams(
# --> 352                 tokenize(preprocess(self.decode(doc))), stop_words)
#     353
#     354         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(x)
#     254
#     255         if self.lowercase:
# --> 256             return lambda x: strip_accents(x.lower())
#     257         else:
#     258             return strip_accents
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# Train Test split

# %%
X_train,X_val,y_train,y_val = train_test_split(X_vectorized,y,test_size=.3, random_state=11)

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train_sm, y_train_sm)
rfc_pred = rfc.predict(X_val)
# Out:
# /Users/mbongenimlotha/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
f1_score(y_val, rfc_pred, average="macro")
# Out:
# 0.5866274461509186
